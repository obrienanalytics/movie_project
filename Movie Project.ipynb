# %% [markdown]
# # **Movie Genre Data Analysis**
# ## **Research Questions**
# ### 1. Which genres are the most common (number of movies made)?
# ### 2. Which genres have high average budget and revenue?
# ### 2.5 Which genres have high average popularity?
# ### 3. Which genres have high average popularity?
# ### 4. Which genres have the highest number of movies with a voting average of greater than or equal to 8?
#
#
# ## **Research Hypotheses**
# ### 1. The best movies, according to voting average, return the highest profit and revenue.
# ### 2. The best movies according to popularity return high profit and revenue.
# ### 3. Highly budgeted movies return high revenue and profit.
# ### 4. Highly budgeted movies have a high popularity.

# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\davea\OneDrive\Documents\Pandas Lesson - Files, Analyst Builder\Projects\Movie Project\imdb_movies.csv")

# %%
pd.set_option('display.max.rows', None)
pd.set_option('display.max.columns', None)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies[movies.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  \
# 2090  Dwight H. Little  Survival is no game
#
#                                                keywords  \
# 2090  martial arts|dystopia|based on video game|mart...
#
#                                                overview  runtime  \
# 2090  In the year of 2039, after World Wars destroy ...       92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date  vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10         110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0

# %%
movies.drop_duplicates(inplace = True)

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []

# %%
movies.dropna(subset = ['genres'], inplace = True)

# %% [markdown]
# ## **Research Questions**
# ### 1. Which genres are the most common (number of movies made)?
# ### 2. Which genres have high average budget and revenue?
# ### 3. Which genres have high average popularity?
# ### 4. Which genres have the highest number of movies with a voting average of less than or equal to 8?

# %%
movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies_genre = movies[['popularity', 'budget', 'revenue', 'original_title', 'runtime', 'genres', 'release_date', 'vote_count', 'vote_average', 'profit']]

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# 1           7.1   228436354
# ...

# %%
from pandas import Series, DataFrame

# %%
split = movies_genre['genres'].str.split('|').apply(Series,1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'
del movies_genre['genres']
movies_genre = movies_genre.join(split)
# Out:
# C:\Users\davea\AppData\Local\Temp\ipykernel_27820\1831005858.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split = movies_genre['genres'].str.split('|').apply(Series,1).stack()

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562           6.5  1363528810           Action
# 0       6/9/15        5562           6.5  1363528810        Adventure
# 0       6/9/15        5562           6.5  1363528810  Science Fiction
# 0       6/9/15        5562           6.5  1363528810         Thriller
# 1      5/13/15        6185           7.1   228436354           Action

# %% [markdown]
# ### 1. Which genres are the most common (number of movies made)?

# %%
movies_genre.groupby('genres_split').count()
# Out:
#                  popularity  budget  revenue  original_title  runtime  \
# genres_split
# Action                 2384    2384     2384            2384     2384
# Adventure              1471    1471     1471            1471     1471
# Animation               699     699      699             699      699
# Comedy                 3793    3793     3793            3793     3793
# Crime                  1354    1354     1354            1354     1354
# Documentary             520     520      520             520      520
# Drama                  4760    4760     4760            4760     4760
# Family                 1231    1231     1231            1231     1231
# Fantasy                 916     916      916             916      916
# Foreign                 188     188      188             188      188
# History                 334     334      334             334      334
# Horror                 1637    1637     1637            1637     1637
# ...

# %%
genres_count = pd.DataFrame(movies_genre.groupby('genres_split')['original_title'].nunique()).sort_values('original_title', ascending=True)

# %%
genres_count
# Out:
#                  original_title
# genres_split
# Western                     163
# TV Movie                    167
# Foreign                     188
# War                         269
# History                     331
# Music                       403
# Documentary                 520
# Animation                   697
# Mystery                     796
# Fantasy                     899
# Science Fiction            1207
# Family                     1211
# Crime                      1337
# Adventure                  1442
# Horror                     1580
# Romance                    1686
# Action                     2339
# Thriller                   2841
# Comedy                     3750
# Drama                      4672

# %%
genres_count['original_title'].plot.pie(title = 'Movies Per Genre in %', autopct = '%1.1f%%', figsize = (11,11))
# Out:
# <Axes: title={'center': 'Movies Per Genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].plot.barh(title = 'Movies Per Genre', color = 'DarkBlue', figsize = (10,9))
# Out:
# <Axes: title={'center': 'Movies Per Genre'}, ylabel='genres_split'>

# %% [markdown]
# ### 2. Which genres have high average budget and revenue?

# %%
genres_avg = movies_genre.groupby('genres_split').mean(numeric_only=True)
pd.options.display.float_format = '{:2f}'.format
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('revenue', ascending = True, inplace = True)

# %%
genres_avg[['budget', 'revenue']].plot.barh(title = 'Budget and Revenue by Genre', color = ('DarkBlue', 'c'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Budget and Revenue by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ### 2.5 Which genres have high average popularity?

# %%
genres_avg.sort_values('profit', ascending = True, inplace = True)

# %%
genres_avg['profit'].plot.barh(title = 'Profit by Genre', color = ('DarkBlue'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Profit by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ### 3. Which genres have high average popularity?

# %%
genres_avg.sort_values('popularity', ascending = True, inplace = True)

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
genres_avg['popularity'].plot.barh(title = 'Popularity by Genre', color = ('DarkBlue'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Popularity by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ### 4. Which genres have the highest number of movies with a voting average of greater than or equal to 8?

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562      6.500000  1363528810           Action
# 0       6/9/15        5562      6.500000  1363528810        Adventure
# 0       6/9/15        5562      6.500000  1363528810  Science Fiction
# 0       6/9/15        5562      6.500000  1363528810         Thriller
# 1      5/13/15        6185      7.100000   228436354           Action

# %%
vote_fifty = movies_genre[(movies_genre['vote_count'] >= 50) & (movies_genre['vote_average'] >= 8)]
vote_zero = movies_genre['vote_average'] >= 8

# %%
genres_vote = pd.DataFrame(vote_fifty.groupby('genres_split').vote_average.nunique()).sort_values('vote_average', ascending = True)

# %%
genres_vote.sort_values(by = 'vote_average', ascending = False)
# Out:
#                  vote_average
# genres_split
# Documentary                 5
# Drama                       5
# Crime                       4
# Action                      2
# War                         2
# Thriller                    2
# Adventure                   2
# Comedy                      2
# History                     2
# Music                       2
# Romance                     2
# Science Fiction             1
# Family                      1
# Horror                      1
# Mystery                     1
# Animation                   1
# Fantasy                     1

# %%
genres_vote['vote_average'].plot.barh(title = 'Vote Average by Genre', color = ('DarkBlue'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Vote Average by Genre'}, ylabel='genres_split'>

# %%
genres_vote['vote_average'].plot.barh(title = 'Vote Average by Genre', color = ('DarkBlue'), figsize = (10,9))
# Out:
# <Axes: title={'center': 'Vote Average by Genre'}, ylabel='genres_split'>

# %% [markdown]
# ## **Research Hypotheses**
# ### 1. The best movies, according to voting average, return the highest profit and revenue.
# ### 2. The best movies according to popularity return high profit and revenue.
# ### 3. Highly budgeted movies return high revenue and profit.
# ### 4. Highly budgeted movies have a high popularity.

# %% [markdown]
# ### 1. The best movies, according to voting average, return the highest profit and revenue.

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562      6.500000  1363528810           Action
# 0       6/9/15        5562      6.500000  1363528810        Adventure
# 0       6/9/15        5562      6.500000  1363528810  Science Fiction
# 0       6/9/15        5562      6.500000  1363528810         Thriller
# 1      5/13/15        6185      7.100000   228436354           Action

# %%
movies.drop_duplicates(inplace = True)
movies['profit'] = movies['revenue'] - movies['budget']
movies_genre = movies[['popularity', 'budget', 'revenue', 'original_title', 'runtime', 'genres', 'release_year','release_date', 'vote_count', 'vote_average', 'profit']]

# %%
movies_counted = movies_genre[movies_genre['vote_count'] >= 50]
numeric_movies = movies_counted.select_dtypes(include=['number'])
spearman_corr = numeric_movies.corr(method='spearman')
print(spearman_corr)
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
movies_counted.plot.scatter(x='vote_average', y = 'profit')
# Out:
# <Axes: xlabel='vote_average', ylabel='profit'>

# %%
import seaborn as sns
sns.regplot(x = 'vote_average', y = 'profit', data = movies_counted, line_kws = {"color": 'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='profit'>

# %% [markdown]
# ### 2. The best movies according to popularity return high profit and revenue.

# %%
movies_counted = movies_genre[movies_genre['vote_count'] >= 50]
numeric_movies = movies_counted.select_dtypes(include=['number'])
spearman_corr = numeric_movies.corr(method='spearman')
print(spearman_corr)
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
import matplotlib.pyplot as plt
sns.regplot(x = 'popularity', y = 'profit', data = movies_counted, line_kws = {"color": 'red'})
plt.figure(figsize = (20,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 3. Highly budgeted movies return high revenue and profit.

# %%
movies_counted.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year release_date  \
# 0  Action|Adventure|Science Fiction|Thriller          2015       6/9/15
# 1  Action|Adventure|Science Fiction|Thriller          2015      5/13/15
# 2         Adventure|Science Fiction|Thriller          2015      3/18/15
# 3   Action|Adventure|Science Fiction|Fantasy          2015     12/15/15
# 4                      Action|Crime|Thriller          2015       4/1/15
#
#    vote_count  vote_average      profit
# ...

# %%
import matplotlib.pyplot as plt
sns.regplot(x = 'budget', y = 'revenue', data = movies_counted, line_kws = {"color": 'red'})
plt.figure(figsize = (20,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
sns.regplot(x = 'budget', y = 'profit', data = movies_counted, line_kws = {"color": 'red'})
plt.figure(figsize = (20,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 4. Highly budgeted movies have a high popularity.

# %%
sns.regplot(x = 'budget', y = 'popularity', data = movies_counted, line_kws = {"color": 'red'})
plt.figure(figsize = (20,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **Bonus Question! We'll investigate Genres by Profit per Year using a Heatmap.**

# %%
split = movies_genre['genres'].str.split('|').apply(Series,1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'
del movies_genre['genres']
movies_genre = movies_genre.join(split)
# Out:
# C:\Users\davea\AppData\Local\Temp\ipykernel_27820\1831005858.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split = movies_genre['genres'].str.split('|').apply(Series,1).stack()

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year release_date  vote_count  vote_average      profit  \
# 0          2015       6/9/15        5562      6.500000  1363528810
# 0          2015       6/9/15        5562      6.500000  1363528810
# 0          2015       6/9/15        5562      6.500000  1363528810
# 0          2015       6/9/15        5562      6.500000  1363528810
# 1          2015      5/13/15        6185      7.100000   228436354
#
#       genres_split
# 0           Action
# 0        Adventure
# 0  Science Fiction
# 0         Thriller
# 1           Action

# %%
time_genre = pd.DataFrame(movies_genre.groupby(['release_year', 'genres_split'])['profit'].mean())

# %%
final_genre = pd.pivot_table(time_genre, values = 'profit', index = ['genres_split'], columns = ['release_year'])

# %%
sns.set(rc={'figure.figsize': (15,10)})
sns.heatmap(final_genre, cmap='coolwarm', linewidths=0.5)
plt.gca().set_title('Genres by Profit per Year', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Genres by Profit per Year')
